# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('/home/luciano/github/Treinamento_R_Python/Seção 31/dados/Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=473525536),
#  DecisionTreeClassifier(max_features='auto', random_state=1584045202),
#  DecisionTreeClassifier(max_features='auto', random_state=2119551785),
#  DecisionTreeClassifier(max_features='auto', random_state=2097593654),
#  DecisionTreeClassifier(max_features='auto', random_state=882218799),
#  DecisionTreeClassifier(max_features='auto', random_state=316447812),
#  DecisionTreeClassifier(max_features='auto', random_state=2057160104),
#  DecisionTreeClassifier(max_features='auto', random_state=1190563561),
#  DecisionTreeClassifier(max_features='auto', random_state=875697693),
#  DecisionTreeClassifier(max_features='auto', random_state=1431513936),
#  DecisionTreeClassifier(max_features='auto', random_state=1549051384),
#  DecisionTreeClassifier(max_features='auto', random_state=615882464),
#  DecisionTreeClassifier(max_features='auto', random_state=755567725),
#  DecisionTreeClassifier(max_features='auto', random_state=2048068236),
#  DecisionTreeClassifier(max_features='auto', random_state=1255619213),
#  DecisionTreeClassifier(max_features='auto', random_state=1416530910),
#  DecisionTreeClassifier(max_features='auto', random_state=1196661078),
#  DecisionTreeClassifier(max_features='auto', random_state=533438416),
#  DecisionTreeClassifier(max_features='auto', random_state=859680337),
#  DecisionTreeClassifier(max_features='auto', random_state=1296489860),
#  DecisionTreeClassifier(max_features='auto', random_state=1519377420),
#  DecisionTreeClassifier(max_features='auto', random_state=701298160),
#  DecisionTreeClassifier(max_features='auto', random_state=955560334),
#  DecisionTreeClassifier(max_features='auto', random_state=1804964903),
#  DecisionTreeClassifier(max_features='auto', random_state=564945010),
#  DecisionTreeClassifier(max_features='auto', random_state=1950411503),
#  DecisionTreeClassifier(max_features='auto', random_state=1378446137),
#  DecisionTreeClassifier(max_features='auto', random_state=1489888960),
#  DecisionTreeClassifier(max_features='auto', random_state=687217169),
#  DecisionTreeClassifier(max_features='auto', random_state=1269595235),
#  DecisionTreeClassifier(max_features='auto', random_state=1519620197),
#  DecisionTreeClassifier(max_features='auto', random_state=611483667),
#  DecisionTreeClassifier(max_features='auto', random_state=1533784731),
#  DecisionTreeClassifier(max_features='auto', random_state=1927861963),
#  DecisionTreeClassifier(max_features='auto', random_state=1939703136),
#  DecisionTreeClassifier(max_features='auto', random_state=1786975477),
#  DecisionTreeClassifier(max_features='auto', random_state=1206071805),
#  DecisionTreeClassifier(max_features='auto', random_state=351063521),
#  DecisionTreeClassifier(max_features='auto', random_state=665516619),
#  DecisionTreeClassifier(max_features='auto', random_state=796338534),
#  DecisionTreeClassifier(max_features='auto', random_state=1122710829),
#  DecisionTreeClassifier(max_features='auto', random_state=1049658647),
#  DecisionTreeClassifier(max_features='auto', random_state=848107171),
#  DecisionTreeClassifier(max_features='auto', random_state=1941682715),
#  DecisionTreeClassifier(max_features='auto', random_state=433116389),
#  DecisionTreeClassifier(max_features='auto', random_state=1395552956),
#  DecisionTreeClassifier(max_features='auto', random_state=2019402030),
#  DecisionTreeClassifier(max_features='auto', random_state=614454561),
#  DecisionTreeClassifier(max_features='auto', random_state=1333059261),
#  DecisionTreeClassifier(max_features='auto', random_state=798224239),
#  DecisionTreeClassifier(max_features='auto', random_state=589479378),
#  DecisionTreeClassifier(max_features='auto', random_state=2131000904),
#  DecisionTreeClassifier(max_features='auto', random_state=79947728),
#  DecisionTreeClassifier(max_features='auto', random_state=234785585),
#  DecisionTreeClassifier(max_features='auto', random_state=301985656),
#  DecisionTreeClassifier(max_features='auto', random_state=1300034211),
#  DecisionTreeClassifier(max_features='auto', random_state=2090118488),
#  DecisionTreeClassifier(max_features='auto', random_state=1489679699),
#  DecisionTreeClassifier(max_features='auto', random_state=1121738347),
#  DecisionTreeClassifier(max_features='auto', random_state=174432877),
#  DecisionTreeClassifier(max_features='auto', random_state=1224372577),
#  DecisionTreeClassifier(max_features='auto', random_state=331491111),
#  DecisionTreeClassifier(max_features='auto', random_state=1304463461),
#  DecisionTreeClassifier(max_features='auto', random_state=788874676),
#  DecisionTreeClassifier(max_features='auto', random_state=1210509466),
#  DecisionTreeClassifier(max_features='auto', random_state=1981074048),
#  DecisionTreeClassifier(max_features='auto', random_state=119798366),
#  DecisionTreeClassifier(max_features='auto', random_state=91391680),
#  DecisionTreeClassifier(max_features='auto', random_state=1882476715),
#  DecisionTreeClassifier(max_features='auto', random_state=249536737),
#  DecisionTreeClassifier(max_features='auto', random_state=1808171267),
#  DecisionTreeClassifier(max_features='auto', random_state=1210560789),
#  DecisionTreeClassifier(max_features='auto', random_state=1824530399),
#  DecisionTreeClassifier(max_features='auto', random_state=236957812),
#  DecisionTreeClassifier(max_features='auto', random_state=138923817),
#  DecisionTreeClassifier(max_features='auto', random_state=549788383),
#  DecisionTreeClassifier(max_features='auto', random_state=1551228644),
#  DecisionTreeClassifier(max_features='auto', random_state=1479072610),
#  DecisionTreeClassifier(max_features='auto', random_state=97723221),
#  DecisionTreeClassifier(max_features='auto', random_state=1698037140),
#  DecisionTreeClassifier(max_features='auto', random_state=146653539),
#  DecisionTreeClassifier(max_features='auto', random_state=44804969),
#  DecisionTreeClassifier(max_features='auto', random_state=1993758641),
#  DecisionTreeClassifier(max_features='auto', random_state=957762396),
#  DecisionTreeClassifier(max_features='auto', random_state=506512103),
#  DecisionTreeClassifier(max_features='auto', random_state=1035533208),
#  DecisionTreeClassifier(max_features='auto', random_state=855981768),
#  DecisionTreeClassifier(max_features='auto', random_state=914968718),
#  DecisionTreeClassifier(max_features='auto', random_state=1362627306),
#  DecisionTreeClassifier(max_features='auto', random_state=228363253),
#  DecisionTreeClassifier(max_features='auto', random_state=1608729213),
#  DecisionTreeClassifier(max_features='auto', random_state=11574388),
#  DecisionTreeClassifier(max_features='auto', random_state=1415081839),
#  DecisionTreeClassifier(max_features='auto', random_state=604668444),
#  DecisionTreeClassifier(max_features='auto', random_state=1207317408),
#  DecisionTreeClassifier(max_features='auto', random_state=253508064),
#  DecisionTreeClassifier(max_features='auto', random_state=1472115088),
#  DecisionTreeClassifier(max_features='auto', random_state=1334002524),
#  DecisionTreeClassifier(max_features='auto', random_state=355112738),
#  DecisionTreeClassifier(max_features='auto', random_state=538147323)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.78
